# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

#1. Load and Tokenize Data
with open('input.txt', 'r') as f:
  text = f.read().lower().split('\n')

tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)
total_words = len(tokenizer.word_index) + 1

#2. Prepare N-gram Sequences
input_sequences = []
for line in text:
  token_list = tokenizer.texts_to_sequences([line])[0]
  for i in range(1, len(token_list)):
    input_sequences.append(token_list[:i+1])

max_seq_len = max(len(seq) for seq in input_sequences)
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len,padding='pre'))
X,y = input_sequences[:,:-1], input_sequences[:,-1]

#3. Build and Train RNN Model
model = Sequential([
    Embedding(total_words, 100, input_length=max_seq_len-1),
  SimpleRNN(50),
  Dense(total_words, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, verbose=1)

while True:
  user_text = input("Enter text (or 'quit' to exit): ")
  if user_text.lower() == 'quit': break
  seq = pad_sequences(tokenizer.texts_to_sequences([user_text]), maxlen=max_seq_len-1, padding='pre')
  pred_idx = np.argmax(model.predict(seq, verbose=0), axis=-1)[0]
  print(f"Predicted next word: {tokenizer.index_word.get(pred_idx, '')}\n")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 5.6005
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.4880
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.4131
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.3179
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2076
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.1075
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9772
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8572
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.7211
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6198
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.4758
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3635
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2386
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1113
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.9879
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.8713
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.7925
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6659
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5361
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4084
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2854
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1707
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.0547
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9337
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.8140
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.6951
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.5831
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.4779
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.3617
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.2717
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1613
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0603
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9590
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8646
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7851
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6992
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.6034
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.6807
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5816
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4304
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3450
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2704
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1956
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1350
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0790
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0206
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.9732
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9227
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.8744
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.8365
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.7915
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.7560
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.7232
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6859
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6579
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6465
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6033
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5727
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5484
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5190
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.4989
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4717
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4502
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4270
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4147
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.3993
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3901
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3698
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3878
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3676
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3371
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.3194
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3001
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2850
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2779
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2688
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2550
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2563
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2481
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2309
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2197
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2116
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2045
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1981
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1910
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1855
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1809
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1736
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1684
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1993
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1820
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1657
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1566
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1480
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1423
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1374
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1334
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1295
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1276
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1226
# Enter text (or 'quit' to exit): machine
# Predicted next word: learning
